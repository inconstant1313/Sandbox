# %% [markdown]
# # Домашнее задание: Работа с Comet
#
# ### Импорт библиотек

# %%
import pandas as pd 
import seaborn as sns

from matplotlib import pyplot as plt
from comet_ml import Experiment
from scipy.stats import shapiro

# %% [markdown]
# ### Настройки Comet

# %%
experiment = Experiment(
    api_key="FMGcghRMqkhXI1wlKqq6zX7bQ",
    project_name="medical-appointment",
    workspace="inconstant1313",
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/inconstant1313/medical-appointment/6db2b42e59b449b587aeea84f5ca9d3d

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_csv('data/KaggleV2-May-2016.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
numeric_data = df.copy()
numeric_data.drop([
    'AppointmentID', 
    'PatientId', 
    'ScheduledDay', 
    'AppointmentDay', 
    'No-show',
    'Gender', 
    'Neighbourhood'
    ], axis=1, inplace = True)
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Age           110527 non-null  int64
#  1   Scholarship   110527 non-null  int64
#  2   Hipertension  110527 non-null  int64
#  3   Diabetes      110527 non-null  int64
#  4   Alcoholism    110527 non-null  int64
#  5   Handcap       110527 non-null  int64
#  6   SMS_received  110527 non-null  int64
# dtypes: int64(7)
# memory usage: 5.9 MB

# %% [markdown]
# ### Визуализация корреляции между 7 числовыми признаками, использованными для обучения модели

# %%
#визуализируем числовые признаки для проверки на нормальность
numeric_data.hist(figsize=(16,14));
experiment.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=9ea4c2b43cd24aa6bc69448ef1be90c0&experimentKey=6db2b42e59b449b587aeea84f5ca9d3d',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=9ea4c2b43cd24aa6bc69448ef1be90c0&experimentKey=6db2b42e59b449b587aeea84f5ca9d3d',
#  'imageId': '9ea4c2b43cd24aa6bc69448ef1be90c0'}

# %% [markdown]
# Поскольку числовые признаки

# %%
experiment.end()
